# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 16     |  |
# | :-------------|:-------------|
# | Floor van de Schaft| 6246648 |
# | Jesse Dijkzeul | 6549256 |
# | Tijn de Nooijer| 6387306 |
#
# | Planning Groep: 16     |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Criteria opgesteld | 11:50 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 12:30 |
# | Pauze 1| 12:30 |
# | Pauze 2| Tijdspanne |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# <img src="Design_pagina_1.png" width="500">
# <img src="Design_pagina_2.png" width="500">
# <img src="Design_pagina_3.png" width="500">
# <img src="Design_pagina_4.png" width="500">
# <img src="Design_pagina_5.png" width="500">
# <img src="Design_pagina_6.png" width="500">

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |Temperatuursensor | Bepalen wanneer een koelkast te lang open staat | De temperatuur mag niet boven de 15 graden celcius stijgen binnen de koelkast.  |
# | |  | De meetnauwkeurigheid moet 3 graden celcius zijn. Het meetbereik zal liggen tussen de -10 tot 20 graden celcius. |
# | |  | Een meetfrequentie van 1 meting per minuut.|
# |Druksensor | Een weegschaal voor elektronica onderdelen (dus voor lichte voorwerpen in dit geval specifiek voor elektronica) | Het gewicht voor de losse componenten ligt rond de 0.01- 10.0 gram, de meetnauwkeurigheid ligt voor een goede onderscheiding rond de 0,01 gram.  |
# | | | Een meetfrequentie van minstens 1 keer per seconde.  |
# | |  | De opstelling waarin de sensor zich bevindt mag niet meer dan 1 mm kunnen verschuiven. |
# |Lichtsensor | Bepalen waar zonnepanelen het best kunnen worden geplaatst. | Lichtinval wordt gemeten met een lichtsensor, er wordt rekening gehouden met daglicht met een intensiteit tussen de 1000 - 25.000 lux. Met een maximale meetonzekerheid van 100 lux. |
# | | | De meetfrequentie zit rond de 1 keer per tien minuten. Met deze meetfrequentie wordt er gedurende de hele dag gemeten. |
# | |  | Voldoet aan bestendigheidsnorm IPX4 volgens IEC-standaard 60529 (beschermd tegen spatwater uit alle richtingen).|
#
# Groep 16 heeft gekozen voor een druksensor.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
#
# Het schema stelt een spanningsdeler voor die bestaat uit een krachtgevoelige weerstand R(F) en een vaste weerstand R₂. De krachtgevoelige weerstand R(F) is aangesloten tussen de voedingsspanning van 5 V en het meetpunt. De vaste weerstand R₂ is verbonden tussen het meetpunt en massa (GND). Het analoge meetsignaal wordt afgenomen op het knooppunt tussen R(F) en R₂ en is aangesloten op de analoge ingang A0 van de Arduino.
#
# De uitgangsspanning $V_{out}$ op A0 wordt bepaald door de spanningsdelerformule:
#
# $$
# V_{out} = V_{in} \cdot \frac{R_2}{R(F) + R_2}
# $$
#
# Aangezien R₂ een vaste weerstand is en R(F) varieert afhankelijk van de uitgeoefende kracht, zal de uitgangsspanning veranderen wanneer de kracht op de sensor toeneemt of afneemt. Bij toenemende kracht neemt de weerstand R(F) af. Hierdoor verandert de spanningsverdeling en dus ook de uitgangsspanning volgens bovenstaande relatie.
#
#
# <img src="Uiteindelijke_schets.png" width="400">

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# **1. Welke variabelen ga je veranderen?**
#
# De massa verandert, doordat er verschillende elektronica onderdelen gewogen gaan worden. (Weerstanden, LED's, kabels)
#
# **2. Over welk bereik ga je deze variabelen veranderen?**
#
# De onderdelen van elektronica wegen niet veel. Het bereik waarover we gaan meten is 0,01 gram tot 5 gram, waarbij:
#
# 0,01 gram de ondergrens vormt (kleine SMD-componenten zoals 0603-weerstanden en kleine halfgeleiders), 5 gram de bovengrens vormt (grotere through-hole componenten en kleine vermogenscomponenten zoals elektrolytische condensatoren of TO-220 behuizingen).
#
# **3. Wat ga je allemaal meten?**
#
# Zoveel mogelijk verschillende elektronica componenten die beschikbaar zijn gesteld in het lokaal. Verschillende waarden weerstanden, condensatoren, kabels/draden die worden gebruikt om in het breadboard te steken.
#
# - Weerstanden (220 en 330 ohm, ofwel een fysiek grote en kleine weerstand)
# - Kabel
# - LED's (groen, geel, rood)
# - Condensator
#
# **4. Hoeveel metingen ga je doen?**
#
# 5 metingen
#
# **5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?**
#
# Met de massagegevens van deze elektronica onderdelen, uit de literatuur gehaald zou een geschikte massa kunnen vergeleken met de gegevens die we hebben gekregen uit de arduino, dan kunnen we normeneren het aantal bits gelijk stellen aan gewicht en zo een curvefit maken.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
#
# De meetopstelling bestaat uit twee afzonderlijk geklemde onderdelen. De druksensor is gemonteerd in een breadboard dat stevig aan de tafel is bevestigd en rust op een houten steunconstructie die eveneens aan de tafel is vastgeklemd.
#
# Het rode, ronde bakje fungeert als opvangschaal voor de objecten waarvan de massa wordt gemeten. De massa van deze schaal, die permanent op de sensor drukt, wordt meegenomen in de berekening en verrekend bij de bepaling van de toegevoegde massa.
#
# Hieronder is de meetopstelling weergegeven:
#
# <img src="klemopstelling_1_goed.png" width="900">
# <img src="klemopstelling_2_goed.png" width="400">
# <img src="klemopstelling_3_goed.png" width="400">

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt
#meetdata
arduinodata = np.array([497,626,686,765,832,822,846])
massadata = np.array([56,100,153,226,312,384,480])
#error
u_arduinodata = 10
u_massadata = 0.5

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.
# %matplotlib inline

from scipy.optimize import curve_fit

# curv fit uitvoeren
P0=(0,0,0)

def modelfunctie(x,a,b,c):
    return a*np.exp(b*x)+c

Popt,pcov = curve_fit(modelfunctie,arduinodata,massadata,p0=P0)
a,b,c = Popt

bits_array = np.arange(np.min(arduinodata),np.max(arduinodata))

# plot
plt.figure()
plt.plot(arduinodata,massadata,".",label="data")
plt.errorbar(arduinodata,massadata,xerr=u_arduinodata,yerr=u_massadata,linestyle="")
plt.plot(bits_array,modelfunctie(bits_array,*Popt),"--", label="curve_fit")
plt.xlabel("bits")
plt.ylabel("massa [g]")
plt.legend()
plt.show()

# curve_fit data
print(a)
print(b)
print(c)
# Out:
# 0.11145202545782924
# 0.009627864692136726
# 52.61403036741962

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# In de beginopstelling functioneerde de sensor, maar de gemeten bits bleven bij lichte voorwerpen bij 0. Dit betekent dat de uitgangsspanning nauwelijks veranderde en dat de Arduino geen onderscheid kon maken tussen kleine massas. Bij het plaatsen van zwaardere voorwerpen werden wel verschillende meetwaarden geregistreerd, wat aangeeft dat het systeem alleen gevoelig was bij grotere krachten op de sensor.
#
# De spanningsdelerformule verteld ons dat $V_{out}$ gevoeliger wordt voor de verandering van $R(F)$ bij het verlagen van $R_2$. De oorspronkelijke weerstand was te groot voor het meetbereik van kleine krachten, waardoor het systeem pas reageerde bij hogere belastingen. De iteratie die is toegepast is het plaatsen van meer weerstanden parallel aan $R_2$. Hierdoor wordt de totale waarde van $R_2$ verlaagd.
#
# Gezien ook met deze opstelling de arduino niet gevoelig was voor kleine massaverschillen, is de opstelling niet verder verandert, maar is bij een tweede iteratie gekozen voor het gebruiken van grotere massa's. Hier erkent de arduino wel verschillende massa's en kunnen de meetwaarden worden gebruikt voor een curve-fit.
#
# Hieronder is een foto in de bijlage waar de uiteindelijke opstelling te zien is die is gebruikt voor de resultaten:
#
#
# <img src="opstelling_nieuw.png" width="1000">

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# Voor het wegen van hele lichte voorwerpen, specifiek de beschikbare elektronica onderdelen in het lokaal, is een druksensor niet geschikt. De weegschaal die is ontworpen liet zien dat de arduino geen onderscheid kon maken bij kleine massaverschillen. Na het varieren tussen weerstanden en het parralelschakelen van weerstanden op $R_2$ gaven de meetwaarden nog steeds geen kloppende waarden tussen verschillende elektronica componenten. Wij zijn er dus niet in geslaagd ons oorspronkelijk doel te bereiken. Het model voor de weegschaal werkt wel voor hogere gewichtsklassen.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
#
# Het schema stelt een spanningsdeler voor die bestaat uit een krachtgevoelige weerstand R(F) en een vaste weerstand R₂. De krachtgevoelige weerstand R(F) is aangesloten tussen de voedingsspanning van 5 V en het meetpunt. De vaste weerstand R₂ is verbonden tussen het meetpunt en massa (GND). Het analoge meetsignaal wordt afgenomen op het knooppunt tussen R(F) en R₂ en is aangesloten op de analoge ingang A0 van de Arduino.
#
# De uitgangsspanning $V_{out}$ op A0 wordt bepaald door de spanningsdelerformule:
#
# $$
# V_{out} = V_{in} \cdot \frac{R_2}{R(F) + R_2}
# $$
#
# Aangezien R₂ een vaste weerstand is en R(F) varieert afhankelijk van de uitgeoefende kracht, zal de uitgangsspanning veranderen wanneer de kracht op de sensor toeneemt of afneemt. Bij toenemende kracht neemt de weerstand R(F) af. Hierdoor verandert de spanningsverdeling en dus ook de uitgangsspanning volgens bovenstaande relatie.
#
#
# <img src="Uiteindelijke_schets.png" width="400">

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
#
# De meetopstelling bestaat uit twee afzonderlijk geklemde onderdelen. De druksensor is gemonteerd in een breadboard dat stevig aan de tafel is bevestigd en rust op een houten steunconstructie die eveneens aan de tafel is vastgeklemd.
#
# Het rode, ronde bakje fungeert als opvangschaal voor de objecten waarvan de massa wordt gemeten. De massa van deze schaal, die permanent op de sensor drukt, wordt meegenomen in de berekening en verrekend bij de bepaling van de toegevoegde massa.
#
# Hieronder is de meetopstelling weergegeven:
#
# <img src="klemopstelling_1_goed.png" width="900">
# <img src="klemopstelling_2_goed.png" width="400">
# <img src="klemopstelling_3_goed.png" width="400">

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# Kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |Temperatuursensor | Bepalen wanneer een koelkast te lang open staat | De temperatuur mag niet boven de 15 graden celcius stijgen binnen de koelkast.  |
# | |  | De meetnauwkeurigheid moet 3 graden celcius zijn. Het meetbereik zal liggen tussen de -10 tot 20 graden celcius. |
# | |  | Een meetfrequentie van 1 meting per minuut.|
# |Druksensor | Een weegschaal voor elektronica onderdelen (dus voor lichte voorwerpen in dit geval specifiek voor elektronica) | Het gewicht voor de losse componenten ligt rond de 0.01- 10.0 gram, de meetnauwkeurigheid ligt voor een goede onderscheiding rond de 0,01 gram.  |
# | | | Een meetfrequentie van minstens 1 keer per seconde.  |
# | |  | De opstelling waarin de sensor zich bevindt mag niet meer dan 1 mm kunnen verschuiven. |
# |Lichtsensor | Bepalen waar zonnepanelen het best kunnen worden geplaatst. | Lichtinval wordt gemeten met een lichtsensor, er wordt rekening gehouden met daglicht met een intensiteit tussen de 1000 - 25.000 lux. Met een maximale meetonzekerheid van 100 lux. |
# | | | De meetfrequentie zit rond de 1 keer per tien minuten. Met deze meetfrequentie wordt er gedurende de hele dag gemeten. |
# | |  | Voldoet aan bestendigheidsnorm IPX4 volgens IEC-standaard 60529 (beschermd tegen spatwater uit alle richtingen).|
#
# Groep 16 heeft gekozen voor een druksensor.

# %% [markdown]
# In de beginopstelling functioneerde de sensor, maar de gemeten bits bleven bij lichte voorwerpen bij 0. Dit betekent dat de uitgangsspanning nauwelijks veranderde en dat de Arduino geen onderscheid kon maken tussen kleine massas. Bij het plaatsen van zwaardere voorwerpen werden wel verschillende meetwaarden geregistreerd, wat aangeeft dat het systeem alleen gevoelig was bij grotere krachten op de sensor.
#
# De spanningsdelerformule verteld ons dat $V_{out}$ gevoeliger wordt voor de verandering van $R(F)$ bij het verlagen van $R_2$. De oorspronkelijke weerstand was te groot voor het meetbereik van kleine krachten, waardoor het systeem pas reageerde bij hogere belastingen. De iteratie die is toegepast is het plaatsen van meer weerstanden parallel aan $R_2$. Hierdoor wordt de totale waarde van $R_2$ verlaagd.
#
# Gezien ook met deze opstelling de arduino niet gevoelig was voor kleine massaverschillen, is de opstelling niet verder verandert, maar is bij een tweede iteratie gekozen voor het gebruiken van grotere massa's. Hier erkent de arduino wel verschillende massa's en kunnen de meetwaarden worden gebruikt voor een curve-fit.
#
# Hieronder is een foto in de bijlage waar de uiteindelijke opstelling te zien is die is gebruikt voor de resultaten:
#
#
# <img src="opstelling_nieuw.png" width="1000">

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# **1. Welke variabelen ga je veranderen?**
#
# De massa verandert, doordat er verschillende elektronica onderdelen gewogen gaan worden. (Weerstanden, LED's, kabels)
#
# **2. Over welk bereik ga je deze variabelen veranderen?**
#
# De onderdelen van elektronica wegen niet veel. Het bereik waarover we gaan meten is 0,01 gram tot 5 gram, waarbij:
#
# 0,01 gram de ondergrens vormt (kleine SMD-componenten zoals 0603-weerstanden en kleine halfgeleiders), 5 gram de bovengrens vormt (grotere through-hole componenten en kleine vermogenscomponenten zoals elektrolytische condensatoren of TO-220 behuizingen).
#
# **3. Wat ga je allemaal meten?**
#
# Zoveel mogelijk verschillende elektronica componenten die beschikbaar zijn gesteld in het lokaal. Verschillende waarden weerstanden, condensatoren, kabels/draden die worden gebruikt om in het breadboard te steken.
#
# - Weerstanden (220 en 330 ohm, ofwel een fysiek grote en kleine weerstand)
# - Kabel
# - LED's (groen, geel, rood)
# - Condensator
#
# **4. Hoeveel metingen ga je doen?**
#
# 5 metingen
#
# **5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?**
#
# Met de massagegevens van deze elektronica onderdelen, uit de literatuur gehaald zou een geschikte massa kunnen vergeleken met de gegevens die we hebben gekregen uit de arduino, dan kunnen we normeneren het aantal bits gelijk stellen aan gewicht en zo een curvefit maken.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
#
# De meetopstelling bestaat uit twee afzonderlijk geklemde onderdelen. De druksensor is gemonteerd in een breadboard dat stevig aan de tafel is bevestigd en rust op een houten steunconstructie die eveneens aan de tafel is vastgeklemd.
#
# Het rode, ronde bakje fungeert als opvangschaal voor de objecten waarvan de massa wordt gemeten. De massa van deze schaal, die permanent op de sensor drukt, wordt meegenomen in de berekening en verrekend bij de bepaling van de toegevoegde massa.
#
# Hieronder is de meetopstelling weergegeven:
#
# <img src="klemopstelling_1_goed.png" width="900">
# <img src="klemopstelling_2_goed.png" width="400">
# <img src="klemopstelling_3_goed.png" width="400">

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt
#meetdata
arduinodata = np.array([497,626,686,765,832,822,846])
massadata = np.array([56,100,153,226,312,384,480])
#error
u_arduinodata = 10
u_massadata = 0.5

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.
# %matplotlib inline

from scipy.optimize import curve_fit

# curv fit uitvoeren
P0=(0,0,0)

def modelfunctie(x,a,b,c):
    return a*np.exp(b*x)+c

Popt,pcov = curve_fit(modelfunctie,arduinodata,massadata,p0=P0)
a,b,c = Popt

bits_array = np.arange(np.min(arduinodata),np.max(arduinodata))

# plot
plt.figure()
plt.plot(arduinodata,massadata,".",label="data")
plt.errorbar(arduinodata,massadata,xerr=u_arduinodata,yerr=u_massadata,linestyle="")
plt.plot(bits_array,modelfunctie(bits_array,*Popt),"--", label="curve_fit")
plt.xlabel("bits")
plt.ylabel("massa [g]")
plt.legend()
plt.show()

# curve_fit data
print(a)
print(b)
print(c)
# Out:
# 0.11145202545782924
# 0.009627864692136726
# 52.61403036741962

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# Voor het wegen van hele lichte voorwerpen, specifiek de beschikbare elektronica onderdelen in het lokaal, is een druksensor niet geschikt. De weegschaal die is ontworpen liet zien dat de arduino geen onderscheid kon maken bij kleine massaverschillen. Na het varieren tussen weerstanden en het parralelschakelen van weerstanden op $R_2$ gaven de meetwaarden nog steeds geen kloppende waarden tussen verschillende elektronica componenten. Wij zijn er dus niet in geslaagd ons oorspronkelijk doel te bereiken. Het model voor de weegschaal werkt wel voor hogere gewichtsklassen.
