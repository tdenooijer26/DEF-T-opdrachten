# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 2 invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in (als in *PR* op GitHub en de link op Brightspace). Zet jullie groepsnummer, studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.
#
# | Groep: 10     |  |
# | :-------------|:-------------|
# | Tijn de Nooijer| 6387306 |
# | Vladimir Ristic| 6507468 |
# | Robert den Haan | 6512186 |
# | Planning Groep: 10     |Tijdstip / Tijdspanne  |
# |---|---|
# |Eerste sanity check|11:15|
# |Tweede sanity check|11:30|
# |Derde sanity check|11:45|
# | Werkende condensator | 12:30 |
# | Klaar met opdracht | 17:30 |
# | groep aanwezig 1| Tijdspanne |
# | groep aanwezig 2| Tijdspanne |
# | Pauze 1| 12:30-13:30 |
# | Pauze 2| Tijdspanne |

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="Condensator_schets.png" alt="Condensator_schets.png" width="400"/>

# %%
# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!
epsilon0 = 8.85e-12
epsilon_r = 2.6
distance = 0.001
def capaciteit_plaat(surface):
    C_formule = (epsilon_r*surface*epsilon0)/distance 
    return C_formule


# Optioneel: schrijf je functie zodanig dat je arrays als input kan geven en (dus) ook arrays als output.

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

C = capaciteit_plaat((10e-2)**2) 

print(f"Berekende capaciteit plaatcondensator groep 10 is {C} pF")
# Out:
# Berekende capaciteit plaatcondensator groep 10 is 2.3010000000000004e-10 pF

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](condensator_opstelling.png)
# ![scope meting 2](scope.png)

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 10| 230.1pF |1,43V | 1.57V |156pF |

# %% [markdown]
# ## *Opdracht 2:* Synthese.

# %% [markdown]
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# ![drie schetsen](Druk.png)
# ![drie schetsen](Bewegen.png)
# ![drie schetsen](Permittiviteit.png)<br>
# De onderste schets geeft weer dat water tussen door de platen van de condensator stroomt en dus de permittiviteit verandert

# %% [markdown]
# ## Opdracht 3: Welke sensor gaan jullie maken?

# %% [markdown]
# Pas deze tekst aan: Wij gaan een sensor maken die de oppervlakte meet.

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.

# %% [markdown]
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](Uiteindelijke_schets.png)

# %%
# Plot hier de verwachte ontwerpgrafiek van jullie sensoren.
import numpy as np
import matplotlib.pyplot as plt
epsilon0 = 8.85e-12 # De constante epsilon0
L = np.linspace(0,0.05,100)
A = (0.14-L)*0.1 # dit is het overlappende oppervlakte van de 2 platen. 

plt.figure()
plt.plot(L*100, capaciteit_plaat( A)*10**12) #Met behulp van literatuur waarde, hebben we epsilon_r = 2.6
plt.xlabel("Lengte $cm$")
plt.ylabel("capiciteit $pF$")
plt.title("capiciteit vs lengte")
plt.show()

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 0 |0 |
# | gemiddelde capaciteit| 161 |800mV |
# | maximale capaciteit| 322 |1600mV |

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.

# %% [markdown]
# #### Voeg hier de foto's van je sensoren in actie in.
# ![meting 1](Afbeelding_1.png)
# ![meting 2](afbeelding_2.png)

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
data = np.array([131.0, 129.8, 128.9, 125.2, 121.9, 120.5, 116.9, 115.5 , 110.5, 106.7, 103.1])
onz_data = np.array([10,10,10,10,10,10,10,10,10,10,10,])

# %%
# Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
from scipy.optimize import curve_fit

afstand =np.array([0,0.5e-2, 1e-2,1.5e-2,2e-2,2.5e-2,3e-2,3.5e-2,4e-2,4.5e-2,5e-2])
onz_afstand = np.array([0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,])
Oppervlak = (14 - 2*afstand)*10

plt.figure()
plt.plot(afstand*100, data, 'k.', label = "data")
plt.plot(L*100, capaciteit_plaat(A)*10**12)
plt.xlabel("afstand $cm$")
plt.ylabel("capiciteit $pF$")
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.

# %% [markdown]
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * Het kan beter vast zitten aan het platform waarover het beweegt zodat er geen contactproblemen zijn.
# * De schaal (als in lengte) waarover een van de platen wordt bewogen can accurater.

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.

# %% [markdown]
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](Afbeelding_1.png)

# %%
# Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# en zet ook de verwachte ontwerpgrafiek erbij

def f(x, a, b): # uit de theorie blijk het verband lineair te zijn
    return a * x + b

popt, pcov = curve_fit(f, afstand, data)
a, b = popt 



plt.figure()
plt.errorbar(afstand, data, xerr=onz_afstand, yerr=onz_data, label = "data")
plt.plot(L, f(L, a, b), 'r--')
plt.plot(L, capaciteit_plaat( A)*10**12)
plt.xlabel("afstand $m$")
plt.ylabel("capiciteit $pF$")
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.

# %% [markdown]
# De sensor is niet geschikt voor het meten van de grootheden. De onzekerheid in de Capaciteit is te groot voor betrouwbare metingen.

# %% [markdown]
# ## Opdracht 11: Kopieer hieronder de leerdoelen.
# 1. Het kunnen gebruiken van de eigenschappen van een elektrische component in een ontwerpproces om een fysische grootheid te meten.
# 2. Kennis hebben van gedrag van elektrische componenten en meetopstellingen.
# 3. Onderdelen van een datasheet zoals een kalibratiegrafiek opstellen, gevoeligheid en onzekerheid beschrijven.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.
#
# # Plot hier de verwachte ontwerpgrafiek van jullie sensoren.
# import numpy as np
# import matplotlib.pyplot as plt
# epsilon0 = 8.85e-12 # De constante epsilon0
# L = np.linspace(0,0.05,100)
# A = (0.14-L)*0.1 # dit is het overlappende oppervlakte van de 2 platen.
#
# plt.figure()
# plt.plot(L*100, capaciteit_plaat( A)*10**12) #Met behulp van literatuur waarde, hebben we epsilon_r = 2.6
# plt.xlabel("Lengte $cm$")
# plt.ylabel("capiciteit $pF$")
# plt.title("capiciteit vs lengte")
# plt.show()
#
#
# #### Opdracht 2 synthese
#
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# ![drie schetsen](Druk.png)
# ![drie schetsen](Bewegen.png)
# ![drie schetsen](Permittiviteit.png)<br>
# De onderste schets geeft weer dat water tussen door de platen van de condensator stroomt en dus de permittiviteit verandert
#
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 10| 230.1pF |1,43V | 1.57V |156pF |
#
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](condensator_opstelling.png)
# ![scope meting 2](scope.png)
#
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="Condensator_schets.png" alt="Condensator_schets.png" width="400"/>

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.
#
# ## Opdracht 5: Invullen tabel LTSpice.
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 0 |0 |
# | gemiddelde capaciteit| 161 |800mV |
# | maximale capaciteit| 322 |1600mV |
#
# # Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
# from scipy.optimize import curve_fit
#
# afstand =np.array([0,0.5e-2, 1e-2,1.5e-2,2e-2,2.5e-2,3e-2,3.5e-2,4e-2,4.5e-2,5e-2])
# onz_afstand = np.array([0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,])
# Oppervlak = (14 - 2*afstand)*10
#
# plt.figure()
# plt.plot(afstand*100, data, 'k.', label = "data")
# plt.plot(L*100, capaciteit_plaat(A)*10**12)
# plt.xlabel("afstand $cm$")
# plt.ylabel("capiciteit $pF$")
# plt.legend()
# plt.show()
#
# ## Opdracht 3: Welke sensor gaan jullie maken?
# Pas deze tekst aan: Wij gaan een sensor maken die de oppervlakte meet.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.
#
# ## Opdracht 7: Plot de kalibratiegrafiek.
# data = np.array([131.0, 129.8, 128.9, 125.2, 121.9, 120.5, 116.9, 115.5 , 110.5, 106.7, 103.1])
# onz_data = np.array([10,10,10,10,10,10,10,10,10,10,10,])
# # Plot hier je gemeten kalibratiegrafiek en plot in dezelfde figuur ook je verwachte ontwerpgrafiek.
# from scipy.optimize import curve_fit
#
# afstand =np.array([0,0.5e-2, 1e-2,1.5e-2,2e-2,2.5e-2,3e-2,3.5e-2,4e-2,4.5e-2,5e-2])
# onz_afstand = np.array([0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,0.1e-2,])
# Oppervlak = (14 - 2*afstand)*10
#
# plt.figure()
# plt.plot(afstand*100, data, 'k.', label = "data")
# plt.plot(L*100, capaciteit_plaat(A)*10**12)
# plt.xlabel("afstand $cm$")
# plt.ylabel("capiciteit $pF$")
# plt.legend()
# plt.show()
# ## Opdracht 8: Vul de tekst aan.
# Onze sensor kan nog verbetered worden door de volgende verbeteringen (minimaal 2):
#
# * Het kan beter vast zitten aan het platform waarover het beweegt zodat er geen contactproblemen zijn.
# * De schaal (als in lengte) waarover een van de platen wordt bewogen can accurater.
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](Afbeelding_1.png)
# # Plot hier je oorspronkelijke en je uiteindelijke kalibratiegrafieken, fit daar een bijpassende lijn door
# # en zet ook de verwachte ontwerpgrafiek erbij
#
# def f(x, a, b): # uit de theorie blijk het verband lineair te zijn
#     return a * x + b
#
# popt, pcov = curve_fit(f, afstand, data)
# a, b = popt
#
#
#
# plt.figure()
# plt.errorbar(afstand, data, xerr=onz_afstand, yerr=onz_data, label = "data")
# plt.plot(L, f(L, a, b), 'r--')
# plt.plot(L, capaciteit_plaat( A)*10**12)
# plt.xlabel("afstand $m$")
# plt.ylabel("capiciteit $pF$")
# plt.legend()
# plt.show()
# ## Opdracht 10: Vul hieronder de conclusie in.
# De sensor is niet geschikt voor het meten van de grootheden. De onzekerheid in de Capaciteit is te groot voor betrouwbare metingen.
